# %% [markdown]
# Github
# 1. Create a new repo (Public, add .readme file) (done)
# 2. copy the link of new repo (done)
#
# Databricks
# 1. Create new git folder in workspace
# 2. Move all folders to git folder
# 3. configuration
#  -make connect to github
#  - install databricks in github
#  - select the right repo
