# %%
# %sql
select * from samples.bakehouse.sales_transactions

# %%
# %sql
create table dev.demo.alpha(id int primary key, name string not null)

# %%
# %sql
CREATE OR REPLACE FUNCTION main.default.calculate_discount(price DOUBLE, discount_pct DOUBLE)
RETURNS DOUBLE
RETURN price * (1 - discount_pct);
