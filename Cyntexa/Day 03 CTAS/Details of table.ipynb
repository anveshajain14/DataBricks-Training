-- %%
%sql
describe dev.demo.drivers

-- %%
%sql
describe history dev.demo.drivers

-- %%
%sql
create table dev.demo.beta (id int, name string) using iceberg

-- %%
%sql
describe extended dev.demo.beta

-- %%
%sql
describe detail dev.demo.beta
