# %% [markdown]
# CTAS : create table as select
# /Volumes/dev/demo/vol/circuits - circuits.csv

# %%
# %sql
Create table dev.demo.circuits_sql as
select *,_metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/vol/circuits - circuits.csv")

# %%
# %sql
select * from dev.demo.circuits_sql limit(5)

# %%
# %sql
create table dev.demo.part_sql as
select *, _metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/vol/part-00000-7951754c-3166-4cb7-8227-a5760c654c14-c000.snappy.parquet")

# %%
# %sql
create table dev.demo.finance_sql as
select *, _metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/vol/financial_dataset.csv")

# %%
# %sql
create table dev.demo.drivers_sql as
select *, _metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/vol/drivers.json")

# %%
# %sql
drop table dev.demo.drivers_sql

# %%
# %sql
create table dev.demo.drivers as
select code, dob, driverId, driverRef,name.forename, name.surname, nationality, number, _metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/vol/drivers.json",format=>"json")
