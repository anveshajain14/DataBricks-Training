# %%
input_path = "/Volumes/dev/demo/vol/financial_dataset.csv"
catalog = "dev"
schema = "demo"
table_name = "financial_dataset"

# %%
spark.read.csv(input_path, header=True, inferSchema=True).write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.{table_name}")

# %%
from pyspark.sql.functions import current_date
df.withColumn("ingestion_date", current_date())
