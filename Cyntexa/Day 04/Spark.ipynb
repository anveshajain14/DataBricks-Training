# %%
spark.version

# %%
employees = [{"name": "John D.", "age": 30},
  {"name": "Alice G.", "age": 25},
  {"name": "Bob T.", "age": 35},
  {"name": "Eve A.", "age": 28}]

df = spark.createDataFrame(employees)

# %%
df.show()

# %%
df.display()

# %% [markdown]
# Spark Reader API

# %%
df = spark.read.csv("/Volumes/dev/demo/vol/financial_dataset.csv")

# %%
df = spark.read.csv("/Volumes/dev/demo/vol/financial_dataset.csv", header = True, inferSchema=True)

# %%
df.display()

# %%
df.filter("AccountType = 'Loan'").explain(True)

# %%
df = spark.read.csv("/Volumes/dev/demo/vol/financial_dataset.csv", header = True, inferSchema=True)

# %%
df.write.mode("overwrite").saveAsTable("dev.demo.financial")

# %%
# %sql
select * from dev.demo.financial

# %%
df = spark.read.csv("/Volumes/dev/demo/vol/financial_dataset.csv", header = True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("dev.demo.financial")

# %%
df = spark.read.json("/Volumes/dev/demo/vol/drivers.json")

# %%
df.display()
